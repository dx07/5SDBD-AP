# %%
# Obsolete
from config import setup
setup()

# %% [markdown]
#  # Projet AP GeoSafe, Evacuation lors de feu
#
#  ## Generator
#  Pour générer les données utilisées après par le projet, il faut utiliser le générateur du projet evacsim

# %%
from docplex.cp.model import CpoModel
from docplex.cp.model import *
import numpy as np
import math

# %% [markdown]
# configuration

# %%
from config_duc import setup
setup()
# Out:
# platform:  linux

# %% [markdown]
# ## modélisation

# %%
def geosafe_model(l, q, eps, r, W, H, d):
    '''       
    Int  Matrix l: length path from i to j = G.l[i,j]. No path ij <--> G.l[i,j] = 0
    Int  Array  q: capacity of node i <--> G.q[i]
    Bool Array  eps: evacuation node 
    Bool Array  r: safe node
    Int  Array  W: initial population at node i <--> W[i]
    Int         H : Time span
    Int  Array  d: deadline to leave the node
    '''
    
    nb_node = q.shape[0]
    nodes = np.arange(nb_node) # id nodes, i.e [1,2,3,4, ...]
    total_population = np.sum(W)

    mdl = CpoModel(name='geosafe')
    
    # == Output ==
    # starting date
    s = np.array( mdl.integer_var_list(nb_node, min=0, max = H, name="s") )
        
    # evacuation rate aka. height of package
#     h = np.array([
#         mdl.integer_var(name='phi[%d]')%(i+1), min=0, max = W[i] for i in range(nb_nodes)
#     ])
    h = np.array( mdl.integer_var_list(nb_node, min=0, max = 100, name="h") )

    # == Intermediate ==
    # node flow of population
    phi = np.matrix([
            [ 
                mdl.integer_var(name='phi[%d,%d]'%(i+1,j)) for j in range(H) 
            ] for i in range(nb_node)
        ])
    
    # ending date (leaving time) of node
    e = np.array( mdl.integer_var_list(nb_node, min=0, max = 150, name= "e") )
    
    for v in range(nb_node):
        if eps[v]:
            mdl.add(
                e[v] == s[v] + W[v]/h[v]
            )
    
    # == Constraints ==
    
    # Time long enough to evacuate (additional)
    for v in nodes[eps]:
        mdl.add( h[v] * H >= W[v] )
    
    # evacuate everyone in evacuation node (???)
    # has been moved above
    
    # Flow at a node u = sum from all of its leaves node epsilon
#     mdl.add(
#         phi[u, t] == np.sum( phi[u, t - l[u,v] - s[eps]] ) \
#             for t in range(H)                                  \
#             for v in np.where(eps)                           \
#             for u in np.where(t)                             
#     )

    # simplified version
#     for u in nodes[np.where(np.logical_and(np.invert(eps), np.invert(r)))]:
        
#         for t in range(H):
            
#             v_arrays = nodes[np.where(
#                                 np.logical_and(
#                                     np.logical_and(
#                                         np.logical_and(
#                                             eps,
#                                             l[:,u] > 0, 
#                                         ),
#                                         s + l[:,u] <= t,
#                                     ),
#                                     t <= e + l[:, u]
#                                 )
#                             )[1]]
            
#             mdl.add(
#                 phi[u, t] == mdl.sum(h[v] for v in v_arrays)
#             )

#     for u in nodes[eps]:
#         mdl.add(
#             mdl.sum(phi[u, t] for t in range(H)) == h[u]
#         )

    for t in range(H):

        # Flow at epsilon should be h during the evacutation period
        for u in nodes[eps]:
            mdl.add( 
                phi[u, t] == h[u]
            )
            
        
        # Flow at a node u = sum from all of its leaves node epsilon
        for u in nodes[np.where(np.logical_and(np.invert(eps), np.invert(r)))]:
            mdl.add(
                phi[u, t] == mdl.sum(h[v] for v in nodes[eps] if l[v,u] != math.inf and s[v] + l[v,u] <= t and t <= e[v] + l[v,u])
            )
    
    # Flow at a node does not excess capacity of arc
    for t in range(H):
        for u in nodes:
            mdl.add(
                phi[u,t] <= q[u]
            )
            
    # Objective
#     mdl.add(
#         minimize(mdl.max(s[eps] + h[eps]/W[eps] - d[eps]))
#     )
    mdl.add(
        minimize(mdl.max(s[u] + W[u]/h[u] - d[u] for u in nodes[eps] ))
    )
    
    return mdl

# %% [markdown]
# ## Unit test:

# %% [markdown]
# - Test input

# %%
import networkx as nx

# %%
G = nx.DiGraph()

global_d = 250 # TODO: delete this one, just for debug

# TODO: Maybe we should use eps = W > 0, so that do not need to use 'eps' attribute?
nodes_state = [
    (1, {'eps': True,  'r': False, 'W': 5, 'q': 4, 'd': global_d}),
    (2, {'eps': True,  'r': False, 'W': 5, 'q': 3, 'd': global_d}),
    (3, {'eps': True,  'r': False, 'W': 5, 'q': 7, 'd': global_d}),
    (4, {'eps': False, 'r': False, 'W': 0, 'q': 3, 'd': global_d}),
    (5, {'eps': False, 'r': False, 'W': 0, 'q': 20, 'd': global_d}),
    (6, {'eps': False, 'r': True,  'W': 0, 'q': 100, 'd': global_d})
]

edges_state = [
    (1, 4, {'l' : 4}),
    (2, 4, {'l' : 3}),
    (4, 5, {'l' : 7}),
    (3, 5, {'l' : 3}),
    (5, 6, {'l' : 10})
]

G.add_nodes_from(nodes_state)
G.add_edges_from(edges_state)

# %% [markdown]
# Node Attribute :

# %%
def _node_attribute_(G, attribute='eps'):
    '''
    Author: Duc Hau :D
    Return a numpy boolean array of attribute
    '''
    values_tmp = nx.get_node_attributes(G, attribute).values()
    return np.array(list(values_tmp))

# %% [markdown]
# - Init model

# %%
# Path length
#l = nx.to_numpy_matrix(G, weight='l')
l = nx.floyd_warshall_numpy(G, weight='l')

# Node capacities
q = _node_attribute_(G, 'q')

# If the node is in EPSILON (evacuating node)
eps = _node_attribute_(G, 'eps')

# If the node is in the ROOT (safe node)
r = _node_attribute_(G, 'r')

# Initial population
W = _node_attribute_(G, 'W')

# Time span
H = 30

# Deadline for evacutation
d = _node_attribute_(G, 'd')

# Solver configuration
ctx = {}

# %%
mdl = geosafe_model(l, q, eps, r, W, H, d)

# %% [markdown]
# - solve model

# %%
mdl.solve()
sol = mdl.solve(Presolve='On', Workers='Auto')
print(sol.get_solver_log())

print('\n\n Result:')
if sol.is_solution():
    sol.print_solution()
else:
    print('Problem does not have solution')
    sol.print_solution()
# Out:
#  ! ----------------------------------------------------------------------------
#  ! Minimization problem - 189 variables, 336 constraints
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 1629.1 (before), 1629.1 (after)
#  !  . Memory usage      : 414.2 kB (before), 414.2 kB (after)
#  ! Using parallel search with 12 workers.
#  ! ----------------------------------------------------------------------------
#  !          Best Branches  Non-fixed    W       Branch decision
#                         0        189                 -
#  + New bound is -247.500
#                         0         41                 -
#  + New bound is -247
#                         0         41    1   F        -
#  + New bound is -245.016
#  *          -245       36  0.00s        1      (gap is 0.0064%)
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! Best objective         : -245 (optimal - effective tol. is 0.0245)
#  ! Best bound             : -245.016
#  ! Number of branches     : 36
#  ! Number of fails        : 13
#  ! Total memory usage     : 1.4 MB (1.4 MB CP Optimizer + 0.1 MB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 3600.0
#  ! ----------------------------------------------------------------------------
#
#
#
#  Result:
# -------------------------------------------------------------------------------
# Model constraints: 336, variables: integer: 189, interval: 0, sequence: 0
# Solve status: Optimal
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0.01 sec
# -------------------------------------------------------------------------------
# Objective values: (-245,)
#           bounds: (-245.016,)
#           gaps: (6.53061224489434e-05,)
# e0: 5
# e1: 5
# e2: 5
# h0: 1
# h1: 1
# h2: 1
# phi[1,0]: 1
# phi[1,10]: 1
# phi[1,11]: 1
# phi[1,12]: 1
# phi[1,13]: 1
# phi[1,14]: 1
# phi[1,15]: 1
# phi[1,16]: 1
# phi[1,17]: 1
# phi[1,18]: 1
# phi[1,19]: 1
# phi[1,1]: 1
# phi[1,20]: 1
# phi[1,21]: 1
# phi[1,22]: 1
# phi[1,23]: 1
# phi[1,24]: 1
# phi[1,25]: 1
# phi[1,26]: 1
# phi[1,27]: 1
# phi[1,28]: 1
# phi[1,29]: 1
# phi[1,2]: 1
# phi[1,3]: 1
# phi[1,4]: 1
# phi[1,5]: 1
# phi[1,6]: 1
# phi[1,7]: 1
# phi[1,8]: 1
# phi[1,9]: 1
# phi[2,0]: 1
# phi[2,10]: 1
# phi[2,11]: 1
# phi[2,12]: 1
# phi[2,13]: 1
# phi[2,14]: 1
# phi[2,15]: 1
# phi[2,16]: 1
# phi[2,17]: 1
# phi[2,18]: 1
# phi[2,19]: 1
# phi[2,1]: 1
# phi[2,20]: 1
# phi[2,21]: 1
# phi[2,22]: 1
# phi[2,23]: 1
# phi[2,24]: 1
# phi[2,25]: 1
# phi[2,26]: 1
# phi[2,27]: 1
# phi[2,28]: 1
# phi[2,29]: 1
# phi[2,2]: 1
# phi[2,3]: 1
# phi[2,4]: 1
# phi[2,5]: 1
# phi[2,6]: 1
# phi[2,7]: 1
# phi[2,8]: 1
# phi[2,9]: 1
# phi[3,0]: 1
# phi[3,10]: 1
# phi[3,11]: 1
# phi[3,12]: 1
# phi[3,13]: 1
# phi[3,14]: 1
# phi[3,15]: 1
# phi[3,16]: 1
# phi[3,17]: 1
# phi[3,18]: 1
# phi[3,19]: 1
# phi[3,1]: 1
# phi[3,20]: 1
# phi[3,21]: 1
# phi[3,22]: 1
# phi[3,23]: 1
# phi[3,24]: 1
# phi[3,25]: 1
# phi[3,26]: 1
# phi[3,27]: 1
# phi[3,28]: 1
# phi[3,29]: 1
# phi[3,2]: 1
# phi[3,3]: 1
# phi[3,4]: 1
# phi[3,5]: 1
# phi[3,6]: 1
# phi[3,7]: 1
# phi[3,8]: 1
# phi[3,9]: 1
# phi[4,0]: 2
# phi[4,10]: 2
# phi[4,11]: 2
# phi[4,12]: 2
# phi[4,13]: 2
# phi[4,14]: 2
# phi[4,15]: 2
# phi[4,16]: 2
# phi[4,17]: 2
# phi[4,18]: 2
# phi[4,19]: 2
# phi[4,1]: 2
# phi[4,20]: 2
# phi[4,21]: 2
# phi[4,22]: 2
# phi[4,23]: 2
# phi[4,24]: 2
# phi[4,25]: 2
# phi[4,26]: 2
# phi[4,27]: 2
# phi[4,28]: 2
# phi[4,29]: 2
# phi[4,2]: 2
# phi[4,3]: 2
# phi[4,4]: 2
# phi[4,5]: 2
# phi[4,6]: 2
# phi[4,7]: 2
# phi[4,8]: 2
# phi[4,9]: 2
# phi[5,0]: 3
# phi[5,10]: 3
# phi[5,11]: 3
# phi[5,12]: 3
# phi[5,13]: 3
# phi[5,14]: 3
# phi[5,15]: 3
# phi[5,16]: 3
# phi[5,17]: 3
# phi[5,18]: 3
# phi[5,19]: 3
# phi[5,1]: 3
# phi[5,20]: 3
# phi[5,21]: 3
# phi[5,22]: 3
# phi[5,23]: 3
# phi[5,24]: 3
# phi[5,25]: 3
# phi[5,26]: 3
# phi[5,27]: 3
# phi[5,28]: 3
# phi[5,29]: 3
# phi[5,2]: 3
# phi[5,3]: 3
# phi[5,4]: 3
# phi[5,5]: 3
# phi[5,6]: 3
# phi[5,7]: 3
# phi[5,8]: 3
# phi[5,9]: 3
# phi[6,0]: -9007199254740991
# phi[6,10]: -9007199254740991
# phi[6,11]: -9007199254740991
# phi[6,12]: -9007199254740991
# phi[6,13]: -9007199254740991
# phi[6,14]: -9007199254740991
# phi[6,15]: -9007199254740991
# phi[6,16]: -9007199254740991
# phi[6,17]: -9007199254740991
# phi[6,18]: -9007199254740991
# phi[6,19]: -9007199254740991
# phi[6,1]: -9007199254740991
# phi[6,20]: -9007199254740991
# phi[6,21]: -9007199254740991
# phi[6,22]: -9007199254740991
# phi[6,23]: -9007199254740991
# phi[6,24]: -9007199254740991
# phi[6,25]: -9007199254740991
# phi[6,26]: -9007199254740991
# phi[6,27]: -9007199254740991
# phi[6,28]: -9007199254740991
# phi[6,29]: -9007199254740991
# phi[6,2]: -9007199254740991
# phi[6,3]: -9007199254740991
# phi[6,4]: -9007199254740991
# phi[6,5]: -9007199254740991
# phi[6,6]: -9007199254740991
# phi[6,7]: -9007199254740991
# phi[6,8]: -9007199254740991
# phi[6,9]: -9007199254740991
# s0: 0
# s1: 0
# s2: 0
